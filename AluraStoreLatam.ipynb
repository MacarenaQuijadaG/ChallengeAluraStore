# %% [markdown]
# <a href="https://colab.research.google.com/github/MacarenaQuijadaG/ChallengeAluraStore/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
tiendas_con_datos = list(enumerate([tienda, tienda2, tienda3, tienda4], start=1))

# Calcular
total_facturacion = [datos['Precio'].sum() for _, datos in tiendas_con_datos]

nombres_de_tiendas = [f"Tienda {num}" for num, _ in tiendas_con_datos]

for num, datos in tiendas_con_datos:
    total = datos['Precio'].sum()
    print(f"🛒 Tienda {num}: $ {total:,.2f}")

# Gráfico
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.bar(nombres_de_tiendas, total_facturacion, color='lightcoral')
plt.title('Ingresos Totales por Tienda')
plt.xlabel('Tienda')
plt.ylabel('Monto en Pesos')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# 🛒 Tienda 1: $ 1,150,880,400.00
# 🛒 Tienda 2: $ 1,116,343,500.00
# 🛒 Tienda 3: $ 1,098,019,600.00
# 🛒 Tienda 4: $ 1,038,375,700.00

# %% [markdown]
# # 2. Ventas por categoría

# %%
for t in tiendas_con_datos:
    print(f"Tienda {t[0]}")

    ventas_por_categoria = (
        t[1].groupby(['Categoría del Producto'])
            .size()
            .sort_values(ascending=False)
            .reset_index(name='Número de Ventas')
    )

    print(ventas_por_categoria)

    df_productos = t[1].groupby('Categoría del Producto')['Producto'].value_counts()
    print(df_productos)

    # Gráfico
    plt.figure(figsize=(10, 6))
    ventas_por_categoria.plot(kind="barh", color='skyblue', title=f"Ventas por Categoría en Tienda {t[0]}")
    plt.xlabel('Número de Ventas')
    plt.ylabel('Categoría del Producto')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
# Out:
# Tienda 1
#     Categoría del Producto  Número de Ventas
# 0                  Muebles               465
# 1             Electrónicos               448
# 2                 Juguetes               324
# 3        Electrodomésticos               312
# 4     Deportes y diversión               284
# 5   Instrumentos musicales               182
# 6                   Libros               173
# 7  Artículos para el hogar               171
# Categoría del Producto   Producto
# Artículos para el hogar  Cubertería                     52
#                          Set de ollas                   43
#                          Set de vasos                   41
#                          Olla de presión                35
# Deportes y diversión     Balón de baloncesto            55
#                          Bicicleta                      54
#                          Vaso térmico                   54
#                          Balón de voleibol              42
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
calificaciones_promedio = [datos['Calificación'].mean() for _, datos in tiendas_con_datos]
nombres_de_tiendas = [f"Tienda {num}" for num, _ in tiendas_con_datos]

for num, datos in tiendas_con_datos:
    total = datos['Precio'].sum()
    print(f"Tienda {num}: $ {total:,.2f}")

for num, datos in tiendas_con_datos:
    calificacion_promedio = datos['Calificación'].mean()
    print(f" Calificación Promedio Tienda {num}: {calificacion_promedio:.2f}")

fig, ax1 = plt.subplots(figsize=(10, 6))

# Gráfico
ax1.bar(nombres_de_tiendas, total_facturacion, color='lightcoral', alpha=0.6, label="Facturación")
ax1.set_xlabel('Tienda')
ax1.set_ylabel('Monto en Pesos', color='lightcoral')
ax1.tick_params(axis='y', labelcolor='lightcoral')

ax2 = ax1.twinx()
ax2.plot(nombres_de_tiendas, calificaciones_promedio, color='gold', marker='o', label="Calificación Promedio", linewidth=2)
ax2.set_ylabel('Calificación Promedio', color='gold')
ax2.tick_params(axis='y', labelcolor='gold')

plt.title('Ingresos Totales y Calificación Promedio por Tienda')
fig.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()
# Out:
# Tienda 1: $ 1,150,880,400.00
# Tienda 2: $ 1,116,343,500.00
# Tienda 3: $ 1,098,019,600.00
# Tienda 4: $ 1,038,375,700.00
#  Calificación Promedio Tienda 1: 3.98
#  Calificación Promedio Tienda 2: 4.04
#  Calificación Promedio Tienda 3: 4.05
#  Calificación Promedio Tienda 4: 4.00

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
import matplotlib.pyplot as plt
import pandas as pd

ventas_por_categoria_tiendas = []

for t in tiendas_con_datos:
    ventas_por_categoria = t[1].groupby('Categoría del Producto').size()
    ventas_por_categoria_tiendas.append(ventas_por_categoria)

    categoria_mas_vendida = ventas_por_categoria.idxmax()
    categoria_menos_vendida = ventas_por_categoria.idxmin()

    print(f"Tienda {t[0]}:")
    print(f"Ventas por Categoría:\n{ventas_por_categoria}")
    print(f"Categoría más vendida: {categoria_mas_vendida} con {ventas_por_categoria.max()} ventas")
    print(f"Categoría menos vendida: {categoria_menos_vendida} con {ventas_por_categoria.min()} ventas\n")


df_ventas = pd.DataFrame(ventas_por_categoria_tiendas).T
df_ventas.columns = [f"Tienda {i+1}" for i in range(len(df_ventas.columns))]

# Gráfico
ax = df_ventas.plot(kind='bar', figsize=(10, 6))
plt.title('Ventas por Categoría en Cada Tienda')
ax.set_xlabel('Categoría del Producto')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Número de Ventas')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# Tienda 1:
# Ventas por Categoría:
# Categoría del Producto
# Artículos para el hogar    171
# Deportes y diversión       284
# Electrodomésticos          312
# Electrónicos               448
# Instrumentos musicales     182
# Juguetes                   324
# Libros                     173
# Muebles                    465
# dtype: int64
# Categoría más vendida: Muebles con 465 ventas
# Categoría menos vendida: Artículos para el hogar con 171 ventas
#
# Tienda 2:
# Ventas por Categoría:
# Categoría del Producto
# Artículos para el hogar    181
# Deportes y diversión       275
# Electrodomésticos          305
# Electrónicos               422
# Instrumentos musicales     224
# Juguetes                   313
# Libros                     197
# Muebles                    442
# dtype: int64
# Categoría más vendida: Muebles con 442 ventas
# Categoría menos vendida: Artículos para el hogar con 181 ventas
#
# Tienda 3:
# Ventas por Categoría:
# Categoría del Producto
# ...

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
import matplotlib.pyplot as plt

envios_promedio = []
colores = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99']

for t in tiendas_con_datos:
    envio_promedio = t[1]['Costo de envío'].mean()
    print(f"Tienda {t[0]}: {envio_promedio:,.2f}")
    envios_promedio.append(envio_promedio)

# Gráfico de pastel
plt.figure(figsize=(8, 6))
plt.pie(envios_promedio, labels=[f"Tienda {t[0]}" for t in tiendas_con_datos], autopct='%1.1f%%',
        startangle=90, colors=colores)
plt.title('Costo de Envío Promedio por Tienda')
plt.tight_layout()
plt.show()
# Out:
# Tienda 1: 26,018.61
# Tienda 2: 25,216.24
# Tienda 3: 24,805.68
# Tienda 4: 23,459.46

# %% [markdown]
# # **Sr Juan**
# Luego de analizar los datos correspondientes a facturación, ventas por categoría, calificación promedio, productos más y menos vendidos y costos de envío por tienda, se concluye que la Tienda 4 es la que presenta menor rentabilidad general. Esta tienda registra la facturación más baja en comparación con las demás, lo que refleja un desempeño comercial limitado. Además, su calificación promedio es una de las más bajas, lo que sugiere una experiencia del cliente deficiente que puede impactar negativamente en la fidelización y atracción de nuevos compradores. Aunque tiene el costo de envío más bajo, este aspecto no logra compensar las debilidades observadas en los demás indicadores. Por estas razones, se recomienda Sr. Juan considerar la venta de la Tienda 4 y enfocar sus esfuerzos en aquellas tiendas con mejor rendimiento, donde el potencial de crecimiento y beneficio es mayor.
